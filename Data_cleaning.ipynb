# %%
import pandas as pd

# %%
df =pd.read_csv('Allyears.csv')

# %%
df.dropna(inplace = True)

# %%
df_split = df["genres"].str.split(",", n = 5, expand = True)

# %%
df["gen_1"] = df_split[0]
df["gen_2"] = df_split[1]
df["gen_3"] = df_split[2]
df["gen_4"] = df_split[3]
df["gen_5"] = df_split[4]

df.head()
# Out:
#    Unnamed: 0  poistion                          track_name            artist  \
# 0           0         1                Locked out of Heaven        Bruno Mars
# 1           1         2                       Call Me Maybe  Carly Rae Jepsen
# 2           2         3  We Are Young (feat. Janelle Monáe)              fun.
# 3           3         4                            Diamonds           Rihanna
# 4           4         5                                Lost       Frank Ocean
#
#    popularity  followers                                             genres  \
# 0          86   44538470                               ['dance pop', 'pop']
# 1          72    5171372  ['canadian pop', 'dance pop', 'electropop', 'p...
# 2          73    3507632  ['baroque pop', 'metropopolis', 'modern rock',...
# 3          70   51162263  ['barbadian pop', 'dance pop', 'pop', 'urban c...
# 4          84   10256027   ['hip hop', 'lgbtq+ hip hop', 'neo soul', 'pop']
#
# ...

# %%
df["gen_1"] = df["gen_1"].str.replace("\['","")
df["gen_1"] = df["gen_1"].str.replace("\']","")
df["gen_1"] = df["gen_1"].str.replace("\'","")
df["gen_1"] = df["gen_1"].str.replace("\[]","None")
df["gen_2"] = df["gen_2"].str.replace("\['","")
df["gen_2"] = df["gen_2"].str.replace("\']","")
df["gen_2"] = df["gen_2"].str.replace("\'","")
df["gen_2"] = df["gen_2"].str.replace("\[]","None")
df["gen_3"] = df["gen_3"].str.replace("\['","")
df["gen_3"] = df["gen_3"].str.replace("\']","")
df["gen_3"] = df["gen_3"].str.replace("\'","")
df["gen_3"] = df["gen_3"].str.replace("\[]","None")
df["gen_4"] = df["gen_4"].str.replace("\['","")
df["gen_4"] = df["gen_4"].str.replace("\']","")
df["gen_4"] = df["gen_4"].str.replace("\'","")
df["gen_4"] = df["gen_4"].str.replace("\[]","None")
df["gen_5"] = df["gen_5"].str.replace("\['","")
df["gen_5"] = df["gen_5"].str.replace("\']","")
df["gen_5"] = df["gen_5"].str.replace("\'","")
df["gen_5"] = df["gen_5"].str.replace("\[]","None")
# Out:
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\600381659.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_1"] = df["gen_1"].str.replace("\['","")
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\600381659.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_1"] = df["gen_1"].str.replace("\']","")
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\600381659.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_1"] = df["gen_1"].str.replace("\[]","None")
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\600381659.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_2"] = df["gen_2"].str.replace("\['","")
# ...

# %%
df
# Out:
#      Unnamed: 0  poistion                          track_name  \
# 0             0         1                Locked out of Heaven
# 1             1         2                       Call Me Maybe
# 2             2         3  We Are Young (feat. Janelle Monáe)
# 3             3         4                            Diamonds
# 4             4         5                                Lost
# ..          ...       ...                                 ...
# 987         987        89                                SNAP
# 988         988        90                   Until I Found You
# 989         989        91                               Shirt
# 990         990        93                       Made You Look
# 991         991        94                       Midnight Rain
#
#                artist  popularity  followers  \
# 0          Bruno Mars          86   44538470
# 1    Carly Rae Jepsen          72    5171372
# 2                fun.          73    3507632
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# poistion              0
# track_name            0
# artist                0
# popularity            0
# followers             0
# genres                0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# speechiness           0
# instrumentalness      0
# liveness              0
# valence               0
# tempo                 0
# duration_ms           0
# time_signature        0
# explicit              0
# track_id              0
# art_id                0
# album                 0
# year                  0
# gen_1                 0
# gen_2                81
# gen_3               328
# gen_4               525
# gen_5               695
# dtype: int64

# %%
df.groupby(by="gen_1").count()
# Out:
#                  Unnamed: 0  poistion  track_name  artist  popularity  \
# gen_1
# None                      4         4           4       4           4
# acoustic pop              2         2           2       2           2
# adult standards           1         1           1       1           1
# afrofuturism              2         2           2       2           2
# alt z                    13        13          13      13          13
# ...                     ...       ...         ...     ...         ...
# san diego rap             2         2           2       2           2
# sertanejo                 1         1           1       1           1
# tropical house            2         2           2       2           2
# uk hip hop                1         1           1       1           1
# viral pop                 1         1           1       1           1
#
#                  followers  genres  danceability  energy  key  ...  \
# ...

# %%
df["gen_1"] = df.gen_1.str.replace(r'(^.*dance.*$)', 'Dance')
df["gen_1"] = df.gen_1.str.replace(r'(^.*emo.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*art.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*edm.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*alt.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*electro.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*clubbing.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*trance.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*step.*$)', 'EDM')
df["gen_1"] = df.gen_1.str.replace(r'(^.*soul.*$)', 'Soul')
df["gen_1"] = df.gen_1.str.replace(r'(^.*country.*$)', 'Country')
df["gen_1"] = df.gen_1.str.replace(r'(^.*r&b.*$)', 'R&B')
df["gen_1"] = df.gen_1.str.replace(r'(^.*folk.*$)', 'Folk')
df["gen_1"] = df.gen_1.str.replace(r'(^.*rock.*$)', 'Rock')
df["gen_1"] = df.gen_1.str.replace(r'(^.*reggae.*$)', 'Reggae')
df["gen_1"] = df.gen_1.str.replace(r'(^.*indie.*$)', 'Indie')
df["gen_1"] = df.gen_1.str.replace(r'(^.*psych.*$)', 'Indie')
df["gen_1"] = df.gen_1.str.replace(r'(^.*K-.*$)', 'KKK')
df["gen_1"] = df.gen_1.str.replace(r'(^.*latin.*$)', 'Latin')
df["gen_1"] = df.gen_1.str.replace(r'(^.*mambo.*$)', 'Latin')
df["gen_1"] = df.gen_1.str.replace(r'(^.*rap.*$)', 'Rap')
df["gen_1"] = df.gen_1.str.replace(r'(^.*boy.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*adult.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*pop.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*afro.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*room.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*comic.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*wave.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*funk.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*neo.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*wood.*$)', 'Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*hop.*$)', 'Hip Hop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*complex.*$)', 'House')
df["gen_1"] = df.gen_1.str.replace(r'(^.*house.*$)', 'House')
df["gen_1"] = df.gen_1.str.replace(r'(^.*KKK.*$)', 'K-Pop')
df["gen_1"] = df.gen_1.str.replace(r'(^.*gen.*$)', 'Other')
df["gen_1"] = df.gen_1.str.replace(r'(^.*writer.*$)', 'Other')
df["gen_1"] = df.gen_1.str.replace(r'(^.*grime.*$)', 'Other')
df["gen_1"] = df.gen_1.str.replace(r'(^.*sertanejo.*$)', 'Other')
# Out:
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\1139525653.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_1"] = df.gen_1.str.replace(r'(^.*dance.*$)', 'Dance')
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\1139525653.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_1"] = df.gen_1.str.replace(r'(^.*emo.*$)', 'EDM')
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\1139525653.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_1"] = df.gen_1.str.replace(r'(^.*art.*$)', 'EDM')
# C:\Users\L_Mul\AppData\Local\Temp\ipykernel_60552\1139525653.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["gen_1"] = df.gen_1.str.replace(r'(^.*edm.*$)', 'EDM')
# ...

# %%
df.groupby(by="gen_1").count()
# Out:
#          Unnamed: 0  poistion  track_name  artist  popularity  followers  \
# gen_1
# Country           8         8           8       8           8          8
# Dance           331       331         331     331         331        331
# EDM              91        91          91      91          91         91
# Folk             16        16          16      16          16         16
# Hip Hop         116       116         116     116         116        116
# House             7         7           7       7           7          7
# Indie            20        20          20      20          20         20
# Latin            13        13          13      13          13         13
# None              4         4           4       4           4          4
# Other             4         4           4       4           4          4
# Pop             224       224         224     224         224        224
# R&B              19        19          19      19          19         19
# ...

# %%
Order_df = df[['poistion', 'track_name', 'artist', 'popularity', 'followers', 'gen_1', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'explicit','track_id', 'art_id', 'album']]

# %%
Order_df.head()
# Out:
#    poistion                          track_name            artist  popularity  \
# 0         1                Locked out of Heaven        Bruno Mars          86
# 1         2                       Call Me Maybe  Carly Rae Jepsen          72
# 2         3  We Are Young (feat. Janelle Monáe)              fun.          73
# 3         4                            Diamonds           Rihanna          70
# 4         5                                Lost       Frank Ocean          84
#
#    followers    gen_1  danceability  energy  key  loudness  ...  \
# 0   44538470    Dance         0.726   0.698    5    -4.165  ...
# 1    5171372      Pop         0.783   0.580    7    -6.548  ...
# 2    3507632      Pop         0.378   0.638   10    -5.576  ...
# 3   51162263      Pop         0.564   0.710   11    -4.920  ...
# 4   10256027  Hip Hop         0.913   0.603    8    -4.892  ...
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# ...

# %%
Order_df.to_csv('AllYears_gen.csv')
