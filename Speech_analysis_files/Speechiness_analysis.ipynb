# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import dataframe_image as dfi
import scipy.stats as st
from scipy.stats import linregress

# %%
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values,marker="8", facecolors="slategrey", edgecolors="black", alpha = 0.7)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="indigo")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title_label)
    print(f"The r-value is: {rvalue**2}")
    correlation = st.pearsonr(Final_df.iloc[:,1],Final_df.iloc[:,12])
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    print(line_eq)
    plt.show()

# %%
Final_df =pd.read_csv('Final_Data_2012_2022.csv')

# %%
Final_df
# Out:
#      Unnamed: 0  poistion                          track_name  \
# 0             0         1                Locked out of Heaven
# 1             1         2                       Call Me Maybe
# 2             2         3  We Are Young (feat. Janelle Monáe)
# 3             3         4                            Diamonds
# 4             4         5                                Lost
# ..          ...       ...                                 ...
# 987         987        89                                SNAP
# 988         988        90                   Until I Found You
# 989         989        91                               Shirt
# 990         990        93                       Made You Look
# 991         991        94                       Midnight Rain
#
#                artist  popularity  followers    gen_1  danceability  energy  \
# 0          Bruno Mars          86   44538470    Dance         0.726   0.698
# ...

# %%
max_s = int(Final_df['speechiness'].idxmax())
min_s = int(Final_df['speechiness'].idxmin())

x = max_s
y = min_s

print(f"The song with the highest speechiness was {Final_df.iat[x,2]} by {Final_df.iat[x,3]} in {Final_df.iat[x,23]} at No.{Final_df.iat[x,1]}")
print(f"The song with the lowest speechiness was {Final_df.iat[y,2]} by {Final_df.iat[y,3]} in {Final_df.iat[y,23]} at No.{Final_df.iat[y,1]}")
# Out:
# The song with the highest speechiness was Yes Indeed by Lil Baby in 2018 at No.14
# The song with the lowest speechiness was Perfect by Ed Sheeran in 2017 at No.10

# %%
#Create Scatter plot of all Songs populatiry vs speechiness 

title_label = "Poistion vs Speechiness"
x_label = 'Top Hits Poistion'
y_label = 'Spotify Speechiness Rating'

  # Compute linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(Final_df.iloc[:,1], Final_df.iloc[:,12])
regress_values = Final_df.iloc[:,1] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
plt.scatter(Final_df.iloc[:,1],Final_df.iloc[:,12],marker="8", facecolors="slategrey", edgecolors="black", alpha = 0.7)
plt.plot(Final_df.iloc[:,1],regress_values,"r-")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title_label)
print(f"The r-value is: {rvalue**2}")
correlation = st.pearsonr(Final_df.iloc[:,1],Final_df.iloc[:,12])
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)

plt.savefig("Speech_scat1.png", bbox_inches = 'tight')
plt.show()
# Out:
# The r-value is: 0.003053302093949737
# The correlation between both factors is 0.06
# y = 0.0x + 0.09

# %%
Final_df['bins'] = pd.cut(x=Final_df['poistion'], bins=[1, 20, 40, 60, 80, 100], labels=['1 to 20', '21 to 40', '41 to 60',
                            '61 to 80', '81 to 100'])

# %%
Final_df['bins'] = Final_df['bins']

# %%
bins_df = Final_df.groupby(by='bins').mean()

# %%
mean_group_all = bins_df['speechiness'].values.tolist()
bins_list = ['1 to 20', '21 to 40', '41 to 60',
                            '61 to 80', '81 to 100']

# %%
plt.bar(bins_list, mean_group_all, color='slategrey', alpha=0.5, align="center")
plt.title("Mean Speechiness for Poistion Groups")
plt.xlabel("Poistion Groups")
plt.ylabel("Mean Speechiness")
plt.savefig("Speech_bar1.png", bbox_inches = 'tight')
plt.show();

# %%
top10_df = Final_df[Final_df['poistion'] < 11]

top10_df.head()
# Out:
#    Unnamed: 0  poistion                          track_name            artist  \
# 0           0         1                Locked out of Heaven        Bruno Mars
# 1           1         2                       Call Me Maybe  Carly Rae Jepsen
# 2           2         3  We Are Young (feat. Janelle Monáe)              fun.
# 3           3         4                            Diamonds           Rihanna
# 4           4         5                                Lost       Frank Ocean
#
#    popularity  followers    gen_1  danceability  energy  key  ...  valence  \
# 0          86   44538470    Dance         0.726   0.698    5  ...    0.867
# 1          72    5171372      Pop         0.783   0.580    7  ...    0.660
# 2          73    3507632      Pop         0.378   0.638   10  ...    0.735
# 3          70   51162263      Pop         0.564   0.710   11  ...    0.393
# 4          84   10256027  Hip Hop         0.913   0.603    8  ...    0.497
#
# ...

# %%
#Create Scatter plot of all Songs populatiry vs speechiness 

title_label = "Poistion vs Speechiness - Top 10"
x_label = 'Top Hits Poistion'
y_label = 'Spotify Speechiness Rating'

  # Compute linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(top10_df.iloc[:,1], top10_df.iloc[:,12])
regress_values = top10_df.iloc[:,1] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
plt.scatter(top10_df.iloc[:,1],top10_df.iloc[:,12],marker="8", facecolors="slategrey", edgecolors="black", alpha = 0.7)
plt.plot(top10_df.iloc[:,1],regress_values,"r-")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title_label)
print(f"The r-value is: {rvalue**2}")
correlation = st.pearsonr(top10_df.iloc[:,1],top10_df.iloc[:,12])
print(f"The correlation between both factors is {round(correlation[0],2)}")
print(line_eq)

plt.savefig("Speech_scattop10.png", bbox_inches = 'tight')
plt.show()
# Out:
# The r-value is: 0.030076461345042268
# The correlation between both factors is -0.17
# y = -0.01x + 0.12

# %%
Final_df.boxplot(column='speechiness', by='bins', grid=False, rot=90, fontsize=15)
title_boxplot = 'Speechiness Outliers'
plt.title( title_boxplot )
plt.suptitle('')
plt.savefig("Speech_box.png", bbox_inches = 'tight')
plt.show()

# %%
#rslt_df = dataframe[dataframe['Percentage'] > 80]

top1_df = Final_df[Final_df['poistion'] < 2]

top1_df.head()
# Out:
#      Unnamed: 0  poistion                      track_name             artist  \
# 0             0         1            Locked out of Heaven         Bruno Mars
# 100         100         1                          Royals              Lorde
# 200         200         1  Happy - From "Despicable Me 2"  Pharrell Williams
# 300         300         1  Uptown Funk (feat. Bruno Mars)        Mark Ronson
# 400         400         1                         Starboy         The Weeknd
#
#      popularity  followers    gen_1  danceability  energy  key  ...  valence  \
# 0            86   44538470    Dance         0.726   0.698    5  ...    0.867
# 100          78    9885762      EDM         0.674   0.428    7  ...    0.337
# 200          80    4077572  Hip Hop         0.647   0.822    5  ...    0.962
# 300          82     983123    Dance         0.856   0.609    0  ...    0.928
# 400          89   53182739      R&B         0.679   0.587    7  ...    0.486
#
# ...

# %%
top1_list = top1_df['speechiness'].tolist()
years = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',]

# %%
plt.bar(years, top1_list, color='slategrey', alpha=0.5, align="center")
plt.title("Speechiness for Top Track")
plt.xlabel("Years")
plt.ylabel("Speechiness")
plt.savefig("Speech_bar2.png", bbox_inches = 'tight')
plt.show();
