# %%
import pandas as pd

# %%
Track12_df =pd.read_csv('2012Year_final.csv')
Track13_df =pd.read_csv('2013Year_final.csv')
Track14_df =pd.read_csv('2014Year_final.csv')
Track15_df =pd.read_csv('2015Year_final.csv')
Track16_df =pd.read_csv('2016Year_final.csv')
Track17_df =pd.read_csv('2017Year_final.csv')
Track18_df =pd.read_csv('2018Year_final.csv')
Track19_df =pd.read_csv('2019Year_final.csv')
Track20_df =pd.read_csv('2020Year_final.csv')
Track21_df =pd.read_csv('2021Year_final.csv')
Track22_df =pd.read_csv('2022Year_final.csv')

# %%
year_all_df= pd.concat([Track12_df, Track13_df, Track14_df, Track15_df, Track16_df, Track17_df,Track18_df, Track19_df,Track20_df,Track21_df, Track22_df])

# %%
year_all_df = year_all_df.reset_index()
year_all_df
# Out:
#      index  Unnamed: 0  poistion                          track_name  \
# 0        0           0         1                Locked out of Heaven
# 1        1           1         2                       Call Me Maybe
# 2        2           2         3  We Are Young (feat. Janelle Monáe)
# 3        3           3         4                            Diamonds
# 4        4           4         5                                Lost
# ..     ...         ...       ...                                 ...
# 987     88          88        89                                SNAP
# 988     89          89        90                   Until I Found You
# 989     90          90        91                               Shirt
# 990     91          91        93                       Made You Look
# 991     92          92        94                       Midnight Rain
#
#                artist  popularity  followers  \
# 0          Bruno Mars          86   44538470
# ...

# %%
year_all_df = year_all_df.drop(['index', 'Unnamed: 0'], axis=1)

# %%
year_all_df.to_csv('AllYears.csv')
