# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Track22_df =pd.read_csv('Resources/2022Year_final.csv')
Track22_df
# Out:
#     Unnamed: 0  poistion                                         track_name  \
# 0            0         1                                          As It Was
# 1            1         2                                          Anti-Hero
# 2            2         3                          Unholy (feat. Kim Petras)
# 3            3         4                                        First Class
# 4            4         5  Running Up That Hill (A Deal With God) - 2018 ...
# ..         ...       ...                                                ...
# 88          88        89                                               SNAP
# 89          89        90                                  Until I Found You
# 90          90        91                                              Shirt
# 91          91        93                                      Made You Look
# 92          92        94                                      Midnight Rain
#
#              artist  popularity  followers  \
# 0      Harry Styles          93   24543919
# 1      Taylor Swift          97   62872493
# 2         Sam Smith         100   20838804
# 3       Jack Harlow          73    2697390
# 4         Kate Bush          81    1544689
# ..              ...         ...        ...
# 88        Rosa Linn          60     150354
# 89  Stephen Sanchez          84     315637
# 90              SZA          89    8785980
# 91   Meghan Trainor          93   12195671
# 92     Taylor Swift          91   62872493
#
#                                                genres  danceability  energy  \
# 0                                             ['pop']         0.520   0.731
# 1                                             ['pop']         0.637   0.643
# 2                      ['dance pop', 'pop', 'uk pop']         0.714   0.472
# 3   ['deep underground hip hop', 'kentucky hip hop...         0.905   0.563
# 4   ['art pop', 'art rock', 'baroque pop', 'new wa...         0.625   0.533
# ..                                                ...           ...     ...
# 88                                          ['alt z']         0.565   0.636
# 89                 ['gen z singer-songwriter', 'pop']         0.346   0.500
# 90                              ['pop', 'r&b', 'rap']         0.824   0.453
# 91   ['dance pop', 'hip pop', 'pop', 'post-teen pop']         0.838   0.525
# 92                                            ['pop']         0.643   0.363
#
#     key  ...  liveness  valence    tempo  duration_ms  time_signature  \
# 0     6  ...    0.3110    0.662  173.930       167303               4
# 1     4  ...    0.1420    0.533   97.008       200690               4
# 2     2  ...    0.2660    0.238  131.121       156943               4
# 3     8  ...    0.1130    0.324  106.998       173948               4
# 4    10  ...    0.0546    0.139  108.296       300840               4
# ..  ...  ...       ...      ...      ...          ...             ...
# 88    0  ...    0.4470    0.525  170.010       179551               4
# 89   10  ...    0.1890    0.191  202.466       176667               3
# 90    3  ...    0.0896    0.552  119.959       181831               4
# 91   10  ...    0.0771    0.884  144.981       134256               4
# 92    0  ...    0.1150    0.230  139.865       174783               4
#
#     explicit                track_id                  art_id  \
# 0      False  4LRPiXqCikLlN15c3yImP7  6KImCVD70vtIoJWnq6nGn3
# 1      False  0V3wPSX9ygBnCm8psDIegu  06HL4z0CvFAxyc27GXpf02
# 2      False  3nqQXoyQOWXiESFLlDF1hG  2wY79sveU1sp5g7SokKOiI
# 3       True  1rDQ4oMwGJI7B4tovsBOxc  2LIk90788K0zvyj2JJVwkJ
# 4      False  29d0nY7TzCoi22XBqDQkiP  1aSxMhuvixZ8h9dK9jIDwL
# ..       ...                     ...                     ...
# 88     False  6zJejIfVYLgjud3lTk4DLB  46xBNx0j6cwY6sD9LgMTm1
# 89     False  6VhuP99TE6gYNQRJIlAWFD  5XKFrudbV4IiuE5WuTPRmT
# 90      True  34ZAzO78a5DAVNrYIGWcPm  7tYKF4w9nC0nq9CsPZTHyP
# 91     False  0QHEIqNKsMoOY5urbzN48u  6JL8zeS1NmiOftqZTRgdTz
# 92     False  3rWDp9tBPQR9z6U5YyRSK4  06HL4z0CvFAxyc27GXpf02
#
#                              album  year
# 0                        As It Was  2022
# 1                        Midnights  2022
# 2        Unholy (feat. Kim Petras)  2022
# 3                      First Class  2022
# 4   Hounds of Love (2018 Remaster)  2022
# ..                             ...   ...
# 88                       SNAP PACK  2022
# 89                 Easy On My Eyes  2022
# 90                           Shirt  2022
# 91                  Takin' It Back  2022
# 92                       Midnights  2022
#
# [93 rows x 24 columns]

# %%
df=pd.read_csv
df1=Track22_df.iloc[:93,[1,3,5]]
df1
# Out:
#     poistion           artist  followers
# 0          1     Harry Styles   24543919
# 1          2     Taylor Swift   62872493
# 2          3        Sam Smith   20838804
# 3          4      Jack Harlow    2697390
# 4          5        Kate Bush    1544689
# ..       ...              ...        ...
# 88        89        Rosa Linn     150354
# 89        90  Stephen Sanchez     315637
# 90        91              SZA    8785980
# 91        93   Meghan Trainor   12195671
# 92        94     Taylor Swift   62872493
#
# [93 rows x 3 columns]

# %%
artist=df1['artist'].tolist()
followers=df1['followers'].tolist()
y=range(len(artist))

plt.figure(figsize=(15,4))
plt.bar(y,followers)
plt.xticks(y,artist,rotation=90);

# %%
plt.scatter(df1.iloc[:,0],df1.iloc[:,2])
